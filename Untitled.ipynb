# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_validate, KFold
from sklearn.preprocessing import StandardScaler, RobustScaler, OneHotEncoder
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import cross_val_score

import numpy as np

# %%
data = pd.read_csv('data/kc_house_data.csv')

# %%
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
len(data[data.waterfront.isna()])
# Out:
# 2376

# %% [markdown]
# I'm gonna exclude the rows without waterfront data because I suspect waterfront is gonna be a strong indicator but I do want to come back and include the 2376 rows later somehow...

# %%
data = data.dropna(subset=['waterfront'])

# %%
len(data)
# Out:
# 19221

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19221 entries, 1 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             19221 non-null  int64
#  1   date           19221 non-null  object
#  2   price          19221 non-null  float64
#  3   bedrooms       19221 non-null  int64
#  4   bathrooms      19221 non-null  float64
#  5   sqft_living    19221 non-null  int64
#  6   sqft_lot       19221 non-null  int64
#  7   floors         19221 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           19164 non-null  float64
#  10  condition      19221 non-null  int64
#  11  grade          19221 non-null  int64
#  12  sqft_above     19221 non-null  int64
#  13  sqft_basement  19221 non-null  object
#  14  yr_built       19221 non-null  int64
#  15  yr_renovated   15809 non-null  float64
#  16  zipcode        19221 non-null  int64
#  17  lat            19221 non-null  float64
#  18  long           19221 non-null  float64
#  19  sqft_living15  19221 non-null  int64
#  20  sqft_lot15     19221 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.2+ MB

# %% [markdown]
# lat and long will likely need to be combined in some way...along with zipcode?

# %%
data.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront          0
# view               57
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3412
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
data.view.value_counts()
# Out:
# 0.0    17312
# 2.0      836
# 3.0      435
# 1.0      291
# 4.0      290
# Name: view, dtype: int64

# %% [markdown]
# view is number of times viewed? is it possible that views implies interest, therefore a higher price?

# %%
data.yr_renovated.value_counts()
# Out:
# 0.0       15157
# 2014.0       64
# 2013.0       29
# 2005.0       27
# 2000.0       25
#           ...
# 1946.0        1
# 1948.0        1
# 1951.0        1
# 1971.0        1
# 1959.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
data.yr_renovated.isna().sum()
# Out:
# 3412

# %% [markdown]
# I'll take 0s to mean never renovated and for expidency's sake drop na's for this and view. Perhaps if I find that any of these three features with problematic data is unemportant then I can come back and add them back in with the columns deleted instead

# %%
data = data.dropna(how='any')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15762 non-null  int64
#  1   date           15762 non-null  object
#  2   price          15762 non-null  float64
#  3   bedrooms       15762 non-null  int64
#  4   bathrooms      15762 non-null  float64
#  5   sqft_living    15762 non-null  int64
#  6   sqft_lot       15762 non-null  int64
#  7   floors         15762 non-null  float64
#  8   waterfront     15762 non-null  float64
#  9   view           15762 non-null  float64
#  10  condition      15762 non-null  int64
#  11  grade          15762 non-null  int64
#  12  sqft_above     15762 non-null  int64
#  13  sqft_basement  15762 non-null  object
#  14  yr_built       15762 non-null  int64
#  15  yr_renovated   15762 non-null  float64
#  16  zipcode        15762 non-null  int64
#  17  lat            15762 non-null  float64
#  18  long           15762 non-null  float64
#  19  sqft_living15  15762 non-null  int64
#  20  sqft_lot15     15762 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 2.6+ MB

# %% [markdown]
# Come back later and check for pattern among built years which lack renovated years (ie NA) (maybe recent?)

# %%
# ONE HOT COLUMNS:
# discrete values:
#     bedrooms - whole numbers
#     bathrooms (by half?)
#     floors
#     waterfront
#     view
#     condition
#     grade
#     zipcode

# possible binary:
#     year renovated into was/wasn't renovated

# %% [markdown]
# let's explore how the data is presented in these columns to see if anything needs to be edited

# %%
data.bedrooms.value_counts()
# Out:
# 3     7120
# 4     5079
# 2     2003
# 5     1183
# 6      192
# 1      141
# 7       23
# 8       10
# 9        6
# 10       3
# 33       1
# 11       1
# Name: bedrooms, dtype: int64

# %%
data.bathrooms.value_counts()
# Out:
# 2.50    4004
# 1.00    2761
# 1.75    2226
# 2.25    1487
# 2.00    1395
# 1.50    1060
# 2.75     853
# 3.00     543
# 3.50     543
# 3.25     428
# 3.75     104
# 4.00     100
# 4.50      75
# 4.25      62
# 0.75      50
# 4.75      17
# 5.00      14
# 5.25      11
# 5.50       8
# 1.25       6
# 6.00       5
# 0.50       3
# 8.00       2
# 5.75       2
# 7.50       1
# 7.75       1
# 6.75       1
# Name: bathrooms, dtype: int64

# %% [markdown]
# QUARTERS!

# %%
data.floors.value_counts()
# Out:
# 1.0    7777
# 2.0    6049
# 1.5    1374
# 3.0     439
# 2.5     117
# 3.5       6
# Name: floors, dtype: int64

# %%
data.waterfront.value_counts()
# Out:
# 0.0    15642
# 1.0      120
# Name: waterfront, dtype: int64

# %%
data.condition.value_counts()
# Out:
# 3    10221
# 4     4137
# 5     1254
# 2      131
# 1       19
# Name: condition, dtype: int64

# %%
data.grade.value_counts()
# Out:
# 7     6539
# 8     4438
# 9     1920
# 6     1482
# 10     832
# 11     290
# 5      167
# 12      66
# 4       16
# 13      11
# 3        1
# Name: grade, dtype: int64

# %%
data.zipcode.value_counts()
# Out:
# 98038    437
# 98103    425
# 98052    416
# 98042    408
# 98115    407
#         ...
# 98010     70
# 98102     65
# 98024     58
# 98148     42
# 98039     36
# Name: zipcode, Length: 70, dtype: int64

# %%
data.yr_built.value_counts()
# Out:
# 2014    400
# 2006    335
# 2005    327
# 2007    308
# 2004    304
#        ...
# 1901     22
# 1902     18
# 1933     18
# 1934     15
# 1935     14
# Name: yr_built, Length: 116, dtype: int64

# %%
data.yr_renovated.value_counts()
# Out:
# 0.0       15111
# 2014.0       64
# 2013.0       29
# 2005.0       27
# 2000.0       25
#           ...
# 1934.0        1
# 1976.0        1
# 1950.0        1
# 1946.0        1
# 1948.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# one hot encoding years built and renovated is easily going to push me up against my column limit. Then again, maybe it won't be too bad? Maybe I compare models with them one hot-ted vs one with them presented as continuious values?

# %% [markdown]
# convert date column to datetime

# %%
data.date = pd.to_datetime(data.date)

# %%
data.date = data.date.apply(lambda x: x.toordinal())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15762 non-null  int64
#  1   date           15762 non-null  int64
#  2   price          15762 non-null  float64
#  3   bedrooms       15762 non-null  int64
#  4   bathrooms      15762 non-null  float64
#  5   sqft_living    15762 non-null  int64
#  6   sqft_lot       15762 non-null  int64
#  7   floors         15762 non-null  float64
#  8   waterfront     15762 non-null  float64
#  9   view           15762 non-null  float64
#  10  condition      15762 non-null  int64
#  11  grade          15762 non-null  int64
#  12  sqft_above     15762 non-null  int64
#  13  sqft_basement  15762 non-null  object
#  14  yr_built       15762 non-null  int64
#  15  yr_renovated   15762 non-null  float64
#  16  zipcode        15762 non-null  int64
#  17  lat            15762 non-null  float64
#  18  long           15762 non-null  float64
#  19  sqft_living15  15762 non-null  int64
#  20  sqft_lot15     15762 non-null  int64
# dtypes: float64(8), int64(12), object(1)
# memory usage: 2.6+ MB

# %%
data.sqft_basement.value_counts()
# Out:
# 0.0       9362
# ?          333
# 600.0      155
# 500.0      151
# 700.0      148
#           ...
# 3260.0       1
# 2000.0       1
# 768.0        1
# 10.0         1
# 475.0        1
# Name: sqft_basement, Length: 283, dtype: int64

# %%
data[data.sqft_basement == '?'][['sqft_living', 'sqft_above', 'sqft_basement']]
# Out:
#        sqft_living  sqft_above sqft_basement
# 6             1715        1715             ?
# 18            1200        1200             ?
# 42            3595        3595             ?
# 79            3450        3450             ?
# 112           1540        1160             ?
# ...            ...         ...           ...
# 21210         1170        1070             ?
# 21357         2800        2800             ?
# 21365          820         820             ?
# 21442         2360        1390             ?
# 21519         2380        2380             ?
#
# [333 rows x 3 columns]

# %% [markdown]
# Confirmed that a value for basement sqft can't be derived from the total sqft_living. Will replace ? with 0

# %%
data.sqft_basement = data.sqft_basement.replace('?', 0.0)
data.sqft_basement = data.sqft_basement.astype('float64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15762 non-null  int64
#  1   date           15762 non-null  int64
#  2   price          15762 non-null  float64
#  3   bedrooms       15762 non-null  int64
#  4   bathrooms      15762 non-null  float64
#  5   sqft_living    15762 non-null  int64
#  6   sqft_lot       15762 non-null  int64
#  7   floors         15762 non-null  float64
#  8   waterfront     15762 non-null  float64
#  9   view           15762 non-null  float64
#  10  condition      15762 non-null  int64
#  11  grade          15762 non-null  int64
#  12  sqft_above     15762 non-null  int64
#  13  sqft_basement  15762 non-null  float64
#  14  yr_built       15762 non-null  int64
#  15  yr_renovated   15762 non-null  float64
#  16  zipcode        15762 non-null  int64
#  17  lat            15762 non-null  float64
#  18  long           15762 non-null  float64
#  19  sqft_living15  15762 non-null  int64
#  20  sqft_lot15     15762 non-null  int64
# dtypes: float64(9), int64(12)
# memory usage: 2.6 MB

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data_sum = pd.get_dummies(data, columns=['waterfront', 'view', 'condition', 'grade'],
                      drop_first=False)
data_sum = data_sum.drop(['id'], axis=1)

# %%
# customary column limit = sqrt(rows)
np.sqrt(len(data))
# Out:
# 125.54680402144851

# %%
data_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 39 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            15762 non-null  int64
#  1   price           15762 non-null  float64
#  2   bedrooms        15762 non-null  int64
#  3   bathrooms       15762 non-null  float64
#  4   sqft_living     15762 non-null  int64
#  5   sqft_lot        15762 non-null  int64
#  6   floors          15762 non-null  float64
#  7   sqft_above      15762 non-null  int64
#  8   sqft_basement   15762 non-null  float64
#  9   yr_built        15762 non-null  int64
#  10  yr_renovated    15762 non-null  float64
#  11  zipcode         15762 non-null  int64
#  12  lat             15762 non-null  float64
#  13  long            15762 non-null  float64
#  14  sqft_living15   15762 non-null  int64
#  15  sqft_lot15      15762 non-null  int64
#  16  waterfront_0.0  15762 non-null  uint8
#  17  waterfront_1.0  15762 non-null  uint8
#  18  view_0.0        15762 non-null  uint8
#  19  view_1.0        15762 non-null  uint8
#  20  view_2.0        15762 non-null  uint8
#  21  view_3.0        15762 non-null  uint8
#  22  view_4.0        15762 non-null  uint8
#  23  condition_1     15762 non-null  uint8
#  24  condition_2     15762 non-null  uint8
#  25  condition_3     15762 non-null  uint8
#  26  condition_4     15762 non-null  uint8
#  27  condition_5     15762 non-null  uint8
#  28  grade_3         15762 non-null  uint8
#  29  grade_4         15762 non-null  uint8
#  30  grade_5         15762 non-null  uint8
#  31  grade_6         15762 non-null  uint8
#  32  grade_7         15762 non-null  uint8
#  33  grade_8         15762 non-null  uint8
#  34  grade_9         15762 non-null  uint8
#  35  grade_10        15762 non-null  uint8
#  36  grade_11        15762 non-null  uint8
#  37  grade_12        15762 non-null  uint8
#  38  grade_13        15762 non-null  uint8
# dtypes: float64(7), int64(9), uint8(23)
# memory usage: 2.4 MB

# %% [markdown]
# Probably too many columns but let's press forward

# %%
# plt.figure(figsize=(150,120))
# sns.heatmap(data_sum.corr().abs(), annot=True)
# plt.savefig("heatmap.png")

# %% [markdown]
# high corelates:
# sqft_living12
# sqft_above
# grade
# sqft_living

# %%
# sns.pairplot(data_sum)
# plt.savefig("pairplot_num.png")

# %%
data_sum.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15',
#        'waterfront_0.0', 'waterfront_1.0', 'view_0.0', 'view_1.0', 'view_2.0',
#        'view_3.0', 'view_4.0', 'condition_1', 'condition_2', 'condition_3',
#        'condition_4', 'condition_5', 'grade_3', 'grade_4', 'grade_5',
#        'grade_6', 'grade_7', 'grade_8', 'grade_9', 'grade_10', 'grade_11',
#        'grade_12', 'grade_13'],
#       dtype='object')

# %%
X = data_sum.drop(['price'], axis=1)
y = data_sum['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11821 entries, 8440 to 9955
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            11821 non-null  int64
#  1   bedrooms        11821 non-null  int64
#  2   bathrooms       11821 non-null  float64
#  3   sqft_living     11821 non-null  int64
#  4   sqft_lot        11821 non-null  int64
#  5   floors          11821 non-null  float64
#  6   sqft_above      11821 non-null  int64
#  7   sqft_basement   11821 non-null  float64
#  8   yr_built        11821 non-null  int64
#  9   yr_renovated    11821 non-null  float64
#  10  zipcode         11821 non-null  int64
#  11  lat             11821 non-null  float64
#  12  long            11821 non-null  float64
#  13  sqft_living15   11821 non-null  int64
#  14  sqft_lot15      11821 non-null  int64
#  15  waterfront_0.0  11821 non-null  uint8
#  16  waterfront_1.0  11821 non-null  uint8
#  17  view_0.0        11821 non-null  uint8
#  18  view_1.0        11821 non-null  uint8
#  19  view_2.0        11821 non-null  uint8
#  20  view_3.0        11821 non-null  uint8
#  21  view_4.0        11821 non-null  uint8
#  22  condition_1     11821 non-null  uint8
#  23  condition_2     11821 non-null  uint8
#  24  condition_3     11821 non-null  uint8
#  25  condition_4     11821 non-null  uint8
#  26  condition_5     11821 non-null  uint8
#  27  grade_3         11821 non-null  uint8
#  28  grade_4         11821 non-null  uint8
#  29  grade_5         11821 non-null  uint8
#  30  grade_6         11821 non-null  uint8
#  31  grade_7         11821 non-null  uint8
#  32  grade_8         11821 non-null  uint8
#  33  grade_9         11821 non-null  uint8
#  34  grade_10        11821 non-null  uint8
#  35  grade_11        11821 non-null  uint8
#  36  grade_12        11821 non-null  uint8
#  37  grade_13        11821 non-null  uint8
# dtypes: float64(6), int64(9), uint8(23)
# memory usage: 1.7 MB

# %%
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

# %%
print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_train, train_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_train, train_preds, squared=False):.4f}")
      
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_test, test_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_test, test_preds, squared=False):.4f}")
# Out:
# Train R2 Score: 0.733
# MAE: 120914.9244
# RMSE: 195096.6794
# Test R2 Score: 0.729
# MAE: 122630.6461
# RMSE: 185306.1142

# %% [markdown]
# try in statsmodels to find feature importance

# %%
import statsmodels.api as sm

model = sm.OLS(y_train, sm.add_constant(X_train))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     950.5
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:35   Log-Likelihood:            -1.6077e+05
# No. Observations:               11821   AIC:                         3.216e+05
# Df Residuals:                   11786   BIC:                         3.219e+05
# Df Model:                          34
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -3.283e+07   6.21e+06     -5.289      0.000    -4.5e+07   -2.07e+07
# date             104.1807     15.973      6.522      0.000      72.872     135.490
# bedrooms        -2.47e+04   2673.959     -9.235      0.000   -2.99e+04   -1.95e+04
# bathrooms        4.54e+04   4333.930     10.477      0.000    3.69e+04    5.39e+04
# sqft_living      153.1410     23.669      6.470      0.000     106.745     199.537
# sqft_lot           0.0625      0.064      0.972      0.331      -0.064       0.189
# floors          2.276e+04   4814.920      4.727      0.000    1.33e+04    3.22e+04
# sqft_above         0.9210     23.621      0.039      0.969     -45.379      47.221
# sqft_basement     -7.4342     23.416     -0.317      0.751     -53.333      38.465
# yr_built       -2218.6954     97.875    -22.669      0.000   -2410.547   -2026.844
# yr_renovated      35.8973      4.918      7.300      0.000      26.258      45.537
# zipcode         -619.6609     43.432    -14.267      0.000    -704.795    -534.527
# lat             6.228e+05   1.41e+04     44.216      0.000    5.95e+05     6.5e+05
# long           -2.057e+05   1.73e+04    -11.880      0.000    -2.4e+05   -1.72e+05
# sqft_living15     18.4026      4.596      4.004      0.000       9.393      27.412
# sqft_lot15        -0.3336      0.094     -3.547      0.000      -0.518      -0.149
# waterfront_0.0  -1.67e+07    3.1e+06     -5.381      0.000   -2.28e+07   -1.06e+07
# waterfront_1.0 -1.613e+07    3.1e+06     -5.197      0.000   -2.22e+07      -1e+07
# view_0.0       -6.684e+06   1.24e+06     -5.384      0.000   -9.12e+06   -4.25e+06
# view_1.0       -6.535e+06   1.24e+06     -5.263      0.000   -8.97e+06    -4.1e+06
# view_2.0       -6.612e+06   1.24e+06     -5.325      0.000   -9.05e+06   -4.18e+06
# view_3.0       -6.532e+06   1.24e+06     -5.261      0.000   -8.97e+06    -4.1e+06
# view_4.0        -6.47e+06   1.24e+06     -5.210      0.000    -8.9e+06   -4.04e+06
# condition_1    -6.583e+06   1.24e+06     -5.300      0.000   -9.02e+06   -4.15e+06
# condition_2    -6.604e+06   1.24e+06     -5.317      0.000   -9.04e+06   -4.17e+06
# condition_3    -6.584e+06   1.24e+06     -5.302      0.000   -9.02e+06   -4.15e+06
# condition_4    -6.552e+06   1.24e+06     -5.278      0.000   -8.99e+06   -4.12e+06
# condition_5     -6.51e+06   1.24e+06     -5.245      0.000   -8.94e+06   -4.08e+06
# grade_3        -3.276e+06   5.93e+05     -5.528      0.000   -4.44e+06   -2.11e+06
# grade_4        -3.427e+06   5.67e+05     -6.050      0.000   -4.54e+06   -2.32e+06
# grade_5         -3.43e+06   5.65e+05     -6.075      0.000   -4.54e+06   -2.32e+06
# grade_6        -3.423e+06   5.65e+05     -6.063      0.000   -4.53e+06   -2.32e+06
# grade_7        -3.392e+06   5.64e+05     -6.009      0.000    -4.5e+06   -2.29e+06
# grade_8        -3.333e+06   5.64e+05     -5.904      0.000   -4.44e+06   -2.23e+06
# grade_9        -3.218e+06   5.65e+05     -5.701      0.000   -4.32e+06   -2.11e+06
# grade_10       -3.053e+06   5.65e+05     -5.407      0.000   -4.16e+06   -1.95e+06
# grade_11       -2.837e+06   5.65e+05     -5.023      0.000   -3.94e+06   -1.73e+06
# grade_12       -2.316e+06   5.65e+05     -4.096      0.000   -3.42e+06   -1.21e+06
# grade_13       -1.127e+06   5.69e+05     -1.979      0.048   -2.24e+06    -1.1e+04
# ==============================================================================
# Omnibus:                     8364.703   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           580294.971
# Skew:                           2.732   Prob(JB):                         0.00
# Kurtosis:                      36.887   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.5e-17. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from yellowbrick.regressor import ResidualsPlot

visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# overfitting

# %% [markdown]
# cut back on features?

# %%
data_sum2 = pd.get_dummies(data, columns=['waterfront'],
                      drop_first=False)
data_sum2 = data_sum2.drop(['id', 'waterfront_0.0'], axis=1)

# %%
X = data_sum2.drop(['price'], axis=1)
y = data_sum2['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_train, train_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_train, train_preds, squared=False):.4f}")
      
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_test, test_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_test, test_preds, squared=False):.4f}")
# Out:
# Train R2 Score: 0.701
# MAE: 128111.1115
# RMSE: 206295.5128
# Test R2 Score: 0.704
# MAE: 128541.8884
# RMSE: 193661.0184

# %% [markdown]
# Worse model but also more generalizable

# %%
from yellowbrick.regressor import ResidualsPlot

visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

# %%
model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     1458.
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:38   Log-Likelihood:            -1.6143e+05
# No. Observations:               11821   AIC:                         3.229e+05
# Df Residuals:                   11801   BIC:                         3.230e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           5.415e+05   1899.024    285.134      0.000    5.38e+05    5.45e+05
# date            1.285e+04   1906.532      6.738      0.000    9108.612    1.66e+04
# bedrooms       -3.917e+04   2491.464    -15.723      0.000   -4.41e+04   -3.43e+04
# bathrooms       3.428e+04   3477.355      9.858      0.000    2.75e+04    4.11e+04
# sqft_living     1.494e+05    2.3e+04      6.505      0.000    1.04e+05    1.94e+05
# sqft_lot        3219.7685   2827.449      1.139      0.255   -2322.497    8762.034
# floors           757.9121   2686.554      0.282      0.778   -4508.178    6024.002
# view            4.108e+04   2267.947     18.113      0.000    3.66e+04    4.55e+04
# condition       1.876e+04   2134.422      8.788      0.000    1.46e+04    2.29e+04
# grade           1.074e+05   3522.876     30.498      0.000    1.01e+05    1.14e+05
# sqft_above      3.741e+04   2.07e+04      1.808      0.071   -3153.870     7.8e+04
# sqft_basement    131.9621   1.09e+04      0.012      0.990   -2.13e+04    2.16e+04
# yr_built       -7.882e+04   2953.985    -26.682      0.000   -8.46e+04    -7.3e+04
# yr_renovated    9932.3780   2028.717      4.896      0.000    5955.759    1.39e+04
# zipcode        -3.202e+04   2435.329    -13.149      0.000   -3.68e+04   -2.72e+04
# lat              8.44e+04   2064.248     40.888      0.000    8.04e+04    8.84e+04
# long           -3.116e+04   2559.596    -12.175      0.000   -3.62e+04   -2.61e+04
# sqft_living15   7872.2297   3286.679      2.395      0.017    1429.797    1.43e+04
# sqft_lot15     -1.016e+04   2840.878     -3.576      0.000   -1.57e+04   -4589.153
# waterfront_1.0  4.922e+04   2076.294     23.705      0.000    4.51e+04    5.33e+04
# ==============================================================================
# Omnibus:                    10648.002   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1313573.105
# Skew:                           3.851   Prob(JB):                         0.00
# Kurtosis:                      54.065   Cond. No.                         39.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# features to drop based on P value, sqft_basement, floors, sqft_lot. keeping sqft_above im keeping because i think it might become important with sqft_basement dropped. it's coliniar with sqft_living but i wonder if it takes more importance than sqft living with sqft_basement dropped

# %%
X = data_sum2.drop(['price', 'sqft_basement', 'floors', 'sqft_lot'], axis=1)
y = data_sum2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_train, train_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_train, train_preds, squared=False):.4f}")
      
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_test, test_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_test, test_preds, squared=False):.4f}")
# Out:
# Train R2 Score: 0.701
# MAE: 128144.2255
# RMSE: 206307.4478
# Test R2 Score: 0.704
# MAE: 128614.6618
# RMSE: 193703.5427

# %%
visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

# %%
model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     1731.
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:39   Log-Likelihood:            -1.6143e+05
# No. Observations:               11821   AIC:                         3.229e+05
# Df Residuals:                   11804   BIC:                         3.230e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           5.415e+05   1898.892    285.154      0.000    5.38e+05    5.45e+05
# date            1.287e+04   1906.036      6.751      0.000    9132.019    1.66e+04
# bedrooms       -3.924e+04   2489.514    -15.763      0.000   -4.41e+04   -3.44e+04
# bathrooms       3.453e+04   3364.279     10.263      0.000    2.79e+04    4.11e+04
# sqft_living     1.494e+05   5324.975     28.056      0.000    1.39e+05     1.6e+05
# view            4.122e+04   2264.283     18.206      0.000    3.68e+04    4.57e+04
# condition       1.865e+04   2130.398      8.753      0.000    1.45e+04    2.28e+04
# grade           1.076e+05   3507.969     30.662      0.000    1.01e+05    1.14e+05
# sqft_above      3.787e+04   4461.756      8.488      0.000    2.91e+04    4.66e+04
# yr_built       -7.881e+04   2880.091    -27.364      0.000   -8.45e+04   -7.32e+04
# yr_renovated    9906.3639   2025.611      4.891      0.000    5935.831    1.39e+04
# zipcode        -3.196e+04   2424.695    -13.183      0.000   -3.67e+04   -2.72e+04
# lat             8.436e+04   2054.633     41.058      0.000    8.03e+04    8.84e+04
# long             -3.1e+04   2544.055    -12.185      0.000    -3.6e+04    -2.6e+04
# sqft_living15   7586.2959   3262.997      2.325      0.020    1190.283     1.4e+04
# sqft_lot15     -7903.1854   2001.884     -3.948      0.000   -1.18e+04   -3979.162
# waterfront_1.0   4.92e+04   2076.049     23.697      0.000    4.51e+04    5.33e+04
# ==============================================================================
# Omnibus:                    10636.520   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1306623.618
# Skew:                           3.845   Prob(JB):                         0.00
# Kurtosis:                      53.928   Cond. No.                         7.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.distplot(y)
# Out:
# /Users/home/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# what about with robust scaler?

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

scaler = RobustScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_train, train_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_train, train_preds, squared=False):.4f}")
      
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_test, test_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_test, test_preds, squared=False):.4f}")
# Out:
# Train R2 Score: 0.701
# MAE: 128144.2255
# RMSE: 206307.4478
# Test R2 Score: 0.704
# MAE: 128614.6618
# RMSE: 193703.5427

# %%
visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     1731.
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:40   Log-Likelihood:            -1.6143e+05
# No. Observations:               11821   AIC:                         3.229e+05
# Df Residuals:                   11804   BIC:                         3.230e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.411e+05   3434.574    128.442      0.000    4.34e+05    4.48e+05
# date            2.391e+04   3541.719      6.751      0.000     1.7e+04    3.09e+04
# bedrooms       -4.343e+04   2754.849    -15.763      0.000   -4.88e+04    -3.8e+04
# bathrooms       3.386e+04   3299.785     10.263      0.000    2.74e+04    4.03e+04
# sqft_living     1.821e+05   6489.305     28.056      0.000    1.69e+05    1.95e+05
# view            5.448e+04   2992.609     18.206      0.000    4.86e+04    6.03e+04
# condition       2.854e+04   3260.721      8.753      0.000    2.21e+04    3.49e+04
# grade           9.214e+04   3004.926     30.662      0.000    8.62e+04     9.8e+04
# sqft_above      4.605e+04   5425.535      8.488      0.000    3.54e+04    5.67e+04
# yr_built        -1.21e+05   4421.098    -27.364      0.000    -1.3e+05   -1.12e+05
# yr_renovated      25.2158      5.156      4.891      0.000      15.109      35.322
# zipcode        -5.083e+04   3855.475    -13.183      0.000   -5.84e+04   -4.33e+04
# lat             1.286e+05   3132.599     41.058      0.000    1.22e+05    1.35e+05
# long           -4.501e+04   3694.110    -12.185      0.000   -5.23e+04   -3.78e+04
# sqft_living15   9764.8547   4200.033      2.325      0.020    1532.096     1.8e+04
# sqft_lot15     -1381.2378    349.869     -3.948      0.000   -2067.038    -695.437
# waterfront_1.0  5.892e+05   2.49e+04     23.697      0.000     5.4e+05    6.38e+05
# ==============================================================================
# Omnibus:                    10636.520   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1306623.618
# Skew:                           3.845   Prob(JB):                         0.00
# Kurtosis:                      53.928   Cond. No.                     5.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# convert yr_renovated to binary

# %%
X['yr_renovated'].value_counts()
# Out:
# 0.0       15111
# 2014.0       64
# 2013.0       29
# 2005.0       27
# 2000.0       25
#           ...
# 1934.0        1
# 1976.0        1
# 1950.0        1
# 1946.0        1
# 1948.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
X = data_sum2.drop(['price', 'sqft_basement', 'floors', 'sqft_lot'], axis=1)

X['renovated'] = X['yr_renovated'].apply(lambda x: 0 if x == 0.0 else 1)
X = X.drop(['yr_renovated'], axis=1)


y = data_sum2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

scaler = RobustScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_train, train_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_train, train_preds, squared=False):.4f}")
      
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_test, test_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_test, test_preds, squared=False):.4f}")
# Out:
# Train R2 Score: 0.701
# MAE: 128147.4619
# RMSE: 206311.2036
# Test R2 Score: 0.704
# MAE: 128618.0246
# RMSE: 193704.6756

# %%
visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     1731.
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:42   Log-Likelihood:            -1.6143e+05
# No. Observations:               11821   AIC:                         3.229e+05
# Df Residuals:                   11804   BIC:                         3.230e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.412e+05   3434.567    128.450      0.000    4.34e+05    4.48e+05
# date            2.391e+04   3541.780      6.750      0.000     1.7e+04    3.08e+04
# bedrooms       -4.343e+04   2754.909    -15.764      0.000   -4.88e+04    -3.8e+04
# bathrooms       3.389e+04   3299.709     10.271      0.000    2.74e+04    4.04e+04
# sqft_living     1.821e+05   6489.421     28.057      0.000    1.69e+05    1.95e+05
# view            5.448e+04   2992.673     18.206      0.000    4.86e+04    6.04e+04
# condition       2.851e+04   3260.527      8.743      0.000    2.21e+04    3.49e+04
# grade           9.215e+04   3004.933     30.666      0.000    8.63e+04     9.8e+04
# sqft_above      4.604e+04   5425.650      8.486      0.000    3.54e+04    5.67e+04
# yr_built        -1.21e+05   4421.094    -27.378      0.000    -1.3e+05   -1.12e+05
# zipcode        -5.083e+04   3855.550    -13.183      0.000   -5.84e+04   -4.33e+04
# lat             1.286e+05   3132.648     41.055      0.000    1.22e+05    1.35e+05
# long           -4.501e+04   3694.174    -12.183      0.000   -5.22e+04   -3.78e+04
# sqft_living15   9750.1217   4200.074      2.321      0.020    1517.285     1.8e+04
# sqft_lot15     -1381.4133    349.875     -3.948      0.000   -2067.226    -695.600
# waterfront_1.0  5.892e+05   2.49e+04     23.696      0.000     5.4e+05    6.38e+05
# renovated       4.989e+04   1.03e+04      4.846      0.000    2.97e+04    7.01e+04
# ==============================================================================
# Omnibus:                    10636.359   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1306513.413
# Skew:                           3.845   Prob(JB):                         0.00
# Kurtosis:                      53.926   Cond. No.                         76.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# zipcode        -0.562154      -0.280086   -0.146111        0.030391
# lat            -0.133840       0.047319   -0.082980       -0.015935
# long            1.000000       0.339699    0.254721       -0.042324
# sqft_living15   0.339699       1.000000    0.181315        0.090588
# sqft_lot15      0.254721       0.181315    1.000000        0.029636
# waterfront_1.0 -0.042324       0.090588    0.029636        1.000000
# renovated      -0.070638      -0.005744    0.002623        0.088194
# price           0.021215       0.581572    0.079402        0.274212
#
#                 renovated     price
# date            -0.023396 -0.001754
# bedrooms         0.017149  0.305489
# bathrooms        0.046515  0.526155
# sqft_living      0.049988  0.706189
# view             0.098536  0.396862
# condition       -0.060384  0.034367
# grade            0.011397  0.664146
# sqft_above       0.018821  0.612014
# yr_built        -0.223860  0.049345
# zipcode          0.068362 -0.049502
# lat              0.032056  0.306607
# long            -0.070638  0.021215
# sqft_living15   -0.005744  0.581572
# sqft_lot15       0.002623  0.079402
# waterfront_1.0   0.088194  0.274212
# renovated        1.000000  0.122432
# price            0.122432  1.000000

# %% [markdown]
# what if i just do sqft_living and bathrooms?

# %%
X = X[['bathrooms', 'sqft_living']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

scaler = RobustScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_train, train_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_train, train_preds, squared=False):.4f}")
      
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")
print(f"MAE: {mean_absolute_error(y_test, test_preds):.4f}")
print(f"RMSE: {mean_squared_error(y_test, test_preds, squared=False):.4f}")
# Out:
# Train R2 Score: 0.504
# MAE: 175230.2264
# RMSE: 265685.7024
# Test R2 Score: 0.479
# MAE: 176662.4286
# RMSE: 257141.2930

# %%
visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     6013.
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:43   Log-Likelihood:            -1.6442e+05
# No. Observations:               11821   AIC:                         3.288e+05
# Df Residuals:                   11818   BIC:                         3.289e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.906e+05   2731.172    179.633      0.000    4.85e+05    4.96e+05
# bathrooms   -9591.4891   3648.190     -2.629      0.009   -1.67e+04   -2440.435
# sqft_living  3.355e+05   4532.779     74.020      0.000    3.27e+05    3.44e+05
# ==============================================================================
# Omnibus:                     8609.524   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           403149.065
# Skew:                           2.999   Prob(JB):                         0.00
# Kurtosis:                      30.974   Cond. No.                         2.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ok very obviously much worse

# %%
X = pd.get_dummies(data_sum2, columns=['zipcode'],
                      drop_first=False)
y = data_sum2['price']

# %%
X = X.drop(['price', 'sqft_basement', 'floors', 'sqft_lot'], axis=1)

X['renovated'] = X['yr_renovated'].apply(lambda x: 0 if x == 0.0 else 1)
X = X.drop(['yr_renovated'], axis=1)


y = data_sum2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

scaler = RobustScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")



visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()


X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# Train R2 Score: 0.810
# Test R2 Score: 0.793
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     594.0
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:45   Log-Likelihood:            -1.5850e+05
# No. Observations:               11821   AIC:                         3.172e+05
# Df Residuals:                   11736   BIC:                         3.178e+05
# Df Model:                          84
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.548e+05   3305.203    137.605      0.000    4.48e+05    4.61e+05
# date            2.443e+04   2736.334      8.927      0.000    1.91e+04    2.98e+04
# bedrooms       -2.645e+04   2047.032    -12.922      0.000   -3.05e+04   -2.24e+04
# bathrooms       1.348e+04   2635.022      5.117      0.000    8318.551    1.86e+04
# sqft_living     1.539e+05   5163.969     29.803      0.000    1.44e+05    1.64e+05
# view              5.7e+04   2386.690     23.883      0.000    5.23e+04    6.17e+04
# condition       2.675e+04   2636.740     10.146      0.000    2.16e+04    3.19e+04
# grade           6.065e+04   2488.204     24.376      0.000    5.58e+04    6.55e+04
# sqft_above      5.944e+04   4386.697     13.550      0.000    5.08e+04     6.8e+04
# yr_built       -4.743e+04   3782.772    -12.538      0.000   -5.48e+04      -4e+04
# lat             4.651e+04   1.78e+04      2.620      0.009    1.17e+04    8.13e+04
# long           -4.789e+04   1.32e+04     -3.623      0.000   -7.38e+04    -2.2e+04
# sqft_living15   1.217e+04   3484.501      3.493      0.000    5340.536     1.9e+04
# sqft_lot15       952.4397    303.063      3.143      0.002     358.385    1546.494
# waterfront_1.0  6.561e+05   1.92e+04     34.158      0.000    6.18e+05    6.94e+05
# zipcode_98001  -1.391e+05   2.47e+04     -5.638      0.000   -1.87e+05   -9.07e+04
# zipcode_98002  -1.003e+05   2.59e+04     -3.867      0.000   -1.51e+05   -4.95e+04
# zipcode_98003  -1.742e+05   2.52e+04     -6.916      0.000   -2.24e+05   -1.25e+05
# zipcode_98004   5.708e+05   1.34e+04     42.578      0.000    5.45e+05    5.97e+05
# zipcode_98005   1.104e+05   1.83e+04      6.048      0.000    7.46e+04    1.46e+05
Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1019646.230
# Skew:                           3.675   Prob(JB):                         0.00
# Kurtosis:                      47.902   Cond. No.                     1.13e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.06e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X = pd.get_dummies(data_sum2, columns=['zipcode'],
                      drop_first=False)
y = data_sum2['price']

X = X.drop(['price', 'sqft_basement', 'floors', 'sqft_lot'], axis=1)

X['renovated'] = X['yr_renovated'].apply(lambda x: 0 if x == 0.0 else 1)
X = X.drop(['yr_renovated'], axis=1)


y = data_sum2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

scaler = RobustScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")



visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()


X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# Train R2 Score: 0.802
# Test R2 Score: 0.817
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     566.2
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:47:46   Log-Likelihood:            -1.5907e+05
# No. Observations:               11821   AIC:                         3.183e+05
# Df Residuals:                   11736   BIC:                         3.189e+05
# Df Model:                          84
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.573e+05   3397.326    134.604      0.000    4.51e+05    4.64e+05
# date            2.391e+04   2859.103      8.362      0.000    1.83e+04    2.95e+04
# bedrooms        -3.11e+04   2119.905    -14.672      0.000   -3.53e+04   -2.69e+04
# bathrooms       1.144e+04   2752.196      4.155      0.000    6041.639    1.68e+04
# sqft_living      1.76e+05   5385.251     32.675      0.000    1.65e+05    1.87e+05
# view            5.394e+04   2503.532     21.545      0.000     4.9e+04    5.88e+04
# condition       2.537e+04   2738.945      9.263      0.000       2e+04    3.07e+04
# grade           5.796e+04   2619.931     22.123      0.000    5.28e+04    6.31e+04
# sqft_above      5.531e+04   4609.053     11.999      0.000    4.63e+04    6.43e+04
# yr_built       -5.071e+04   3952.715    -12.830      0.000   -5.85e+04    -4.3e+04
# lat             4.866e+04   1.89e+04      2.580      0.010    1.17e+04    8.56e+04
# long           -4.091e+04   1.39e+04     -2.938      0.003   -6.82e+04   -1.36e+04
# sqft_living15   1.009e+04   3625.898      2.783      0.005    2984.931    1.72e+04
# sqft_lot15       890.6076    304.157      2.928      0.003     294.409    1486.807
# waterfront_1.0  6.896e+05   1.95e+04     35.316      0.000    6.51e+05    7.28e+05
# zipcode_98001  -1.372e+05   2.58e+04     -5.307      0.000   -1.88e+05   -8.65e+04
# zipcode_98002  -9.539e+04   2.73e+04     -3.488      0.000   -1.49e+05   -4.18e+04
# zipcode_98178  -1.488e+05   1.56e+04     -9.567      0.000   -1.79e+05   -1.18e+05
# zipcode_98188  -1.429e+05   2.26e+04     -6.330      0.000   -1.87e+05   -9.86e+04
# zipcode_98198  -1.718e+05   2.14e+04     -8.043      0.000   -2.14e+05    -1.3e+05
# zipcode_98199   1.407e+05   1.98e+04      7.112      0.000    1.02e+05    1.79e+05
# renovated       1.878e+04   8356.540      2.247      0.025    2396.840    3.52e+04
# ==============================================================================
# Omnibus:                    11938.805   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2648208.533
# Skew:                           4.489   Prob(JB):                         0.00
# Kurtosis:                      75.774   Cond. No.                     1.12e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.36e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
scaler = RobustScaler()
crossvalidation = 3
crossvalidation = KFold(n_splits=10, shuffle=True)

X_scaled = scaler.fit_transform(X)

scores = cross_val_score(lr, X_scaled, y, cv=crossvalidation)

scores
# Out:
# array([0.77915927, 0.81267007, 0.83464387, 0.80225297, 0.75216347,
#        0.81041786, 0.80009483, 0.82782909, 0.78417436, 0.82562628])

# %%
print(f"Scores: {scores.mean():.3f} +- {scores.std():.3f}")
# Out:
# Scores: 0.803 +- 0.024

# %% [markdown]
# dropping sqft_lot15 for its small coefifcient

# %%
X = X.drop(["sqft_lot15"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

scaler = RobustScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LinearRegression()

lr.fit(X_train_scaled, y_train)

train_preds = lr.predict(X_train_scaled)
test_preds = lr.predict(X_test_scaled)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")



visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()


X_train_scaled = pd.DataFrame(X_train_scaled, columns = X.columns)

y_train = y_train.values.reshape(-1,1)

model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# Train R2 Score: 0.701
# Test R2 Score: 0.703
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     1973.
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        12:52:13   Log-Likelihood:            -1.6133e+05
# No. Observations:               11821   AIC:                         3.227e+05
# Df Residuals:                   11806   BIC:                         3.228e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          4.421e+05   3355.154    131.769      0.000    4.36e+05    4.49e+05
# date           2.218e+04   3508.826      6.322      0.000    1.53e+04    2.91e+04
# bedrooms      -4.171e+04   2721.501    -15.327      0.000    -4.7e+04   -3.64e+04
# bathrooms      4.023e+04   3220.829     12.492      0.000    3.39e+04    4.65e+04
# sqft_living    1.683e+05   6502.903     25.879      0.000    1.56e+05    1.81e+05
# view           5.194e+04   2957.843     17.561      0.000    4.61e+04    5.77e+04
# condition      2.857e+04   3172.906      9.006      0.000    2.24e+04    3.48e+04
# grade          9.046e+04   2991.990     30.236      0.000    8.46e+04    9.63e+04
# sqft_above     4.783e+04   5452.558      8.772      0.000    3.71e+04    5.85e+04
# yr_built       -1.23e+05   4068.310    -30.245      0.000   -1.31e+05   -1.15e+05
# lat            1.304e+05   3073.982     42.409      0.000    1.24e+05    1.36e+05
# long          -4.579e+04   3598.418    -12.724      0.000   -5.28e+04   -3.87e+04
# sqft_living15  1.343e+04   4157.282      3.231      0.001    5285.259    2.16e+04
# waterfront     6.353e+05    2.3e+04     27.613      0.000     5.9e+05     6.8e+05
# zipcode       -4.865e+04   3838.980    -12.673      0.000   -5.62e+04   -4.11e+04
# ==============================================================================
# Omnibus:                    10836.752   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1517535.718
# Skew:                           3.925   Prob(JB):                         0.00
# Kurtosis:                      57.949   Cond. No.                         25.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_train_scaled
# Out:
#            date  bedrooms  bathrooms  sqft_living  view  condition  grade  \
# 0     -0.228571       1.0   1.666667     2.610619   0.0        0.0    5.0
# 1     -0.480952       0.0   0.666667    -0.070796   0.0        0.0    3.0
# 2      0.471429       0.0  -0.333333    -0.415929   0.0       -1.0   -1.0
# 3     -0.300000       0.0   0.333333     0.477876   0.0        0.0    3.0
# 4     -0.561905       2.0   0.666667     0.327434   0.0        0.0    1.0
# ...         ...       ...        ...          ...   ...        ...    ...
# 11816  0.285714       1.0   0.666667     1.088496   0.0        0.0    2.0
# 11817  0.600000       0.0   0.000000    -0.601770   0.0        0.0    1.0
# 11818 -0.080952       1.0   0.333333     0.415929   0.0        0.0    1.0
# 11819 -0.400000       1.0   0.333333     1.230088   0.0        0.0    2.0
# 11820 -0.776190       1.0   0.333333     1.000000   0.0        0.0    1.0
#
#        sqft_above  yr_built       lat      long  sqft_living15  waterfront  \
# 0        3.235294  0.477273  0.217949  0.004902       1.977273         0.0
# 1        0.127451  0.818182 -0.192783  0.769608       0.534091         0.0
# 2       -0.117647 -1.227273 -0.099715 -0.264706      -0.545455         0.0
# 3        0.872549  0.340909 -0.933998  1.004902       0.920455         0.0
# 4       -0.254902 -0.363636  0.879867 -0.647059       0.602273         0.0
# ...           ...       ...       ...       ...            ...         ...
# 11816    1.549020  0.863636  0.099715  0.848039       1.886364         0.0
# 11817   -0.323529  0.863636  0.383666 -0.828431      -0.090909         0.0
# 11818    0.803922  0.704545 -1.000000  0.946078       0.840909         0.0
# 11819    1.705882  0.522727 -0.304368  0.583333       1.943182         0.0
# 11820    1.450980  0.750000  0.510446  0.558824       1.363636         0.0
#
#         zipcode
# 0     -0.305882
# 1     -0.447059
# 2      0.623529
# 3     -0.317647
# 4      1.317647
# ...         ...
# 11816  0.105882
# 11817  1.576471
# 11818 -0.317647
# 11819 -0.070588
# 11820 -0.152941
#
# [11821 rows x 14 columns]

# %%
scaler = RobustScaler()
crossvalidation = 3
crossvalidation = KFold(n_splits=10, shuffle=True)

X_scaled = scaler.fit_transform(X)

scores = cross_val_score(lr, X_scaled, y, cv=crossvalidation)

scores
# Out:
# array([0.79586923, 0.79570374, 0.80658496, 0.74199695, 0.84495689,
#        0.78551157, 0.80479301, 0.82724606, 0.81666964, 0.79856581])

# %%
print(f"Scores: {scores.mean():.3f} +- {scores.std():.3f}")
# Out:
# Scores: 0.802 +- 0.026

# %% [markdown]
# column transformation and sklearn onehotencoder

# %%
X.columns[:13]
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'view', 'condition',
#        'grade', 'sqft_above', 'yr_built', 'lat', 'long', 'sqft_living15',
#        'waterfront_1.0'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cat_cols = ['date', 'bedrooms', 'bathrooms', 'sqft_living', 'view', 'condition',
       'grade', 'sqft_above', 'yr_built', 'lat', 'long', 'sqft_living15',
       'waterfront', 'zipcode']

# %%
encoder = OneHotEncoder(categories = 'auto', drop = 'if_binary')
ct = ColumnTransformer(transformers=[('ohe', encoder, ['waterfront', 'zipcode'])], remainder='passthrough')

# %%
X = data[cat_cols]
X['waterfront'] = X['waterfront'].astype('str', errors='raise')
# Out:
# <ipython-input-179-6d7df4120972>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['waterfront'] = X['waterfront'].astype('str', errors='raise')

# %%
y = data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y)

ct.fit(X_train)

X_train_ohe = ct.transform(X_train)
X_test_ohe = ct.transform(X_test)

# %%
# scaler = StandardScaler()

# scaler.fit(X_train_ohe)

# X_train_scaled = scaler.transform(X_train_ohe)
# X_test_scaled = scaler.transform(X_test_ohe)

lr = LinearRegression()

lr.fit(X_train_ohe, y_train)

train_preds = lr.predict(X_train_ohe)
test_preds = lr.predict(X_test_ohe)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")

crossvalidation = KFold(shuffle=True)

scores = cross_val_score(lr, X, y, cv=crossvalidation)

print(f"Scores: {scores.mean():.3f} +- {scores.std():.3f}")

# visualizer = ResidualsPlot(lr)

# visualizer.fit(X_train_ohe.toarray(), y_train)
# visualizer.score(X_test_ohe.toarray(), y_test)
# visualizer.show()



y_train = y_train.values.reshape(-1,1)

scaler = RobustScaler()

scaler.fit(X_train_scaled)

X_train_scaled = scaler.transform(X_train_scaled)

X_train_scaled = pd.DataFrame(data = X_train_ohe.toarray(), columns = ct.get_feature_names())


model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# Train R2 Score: 0.809
# Test R2 Score: 0.795
# Scores: 0.699 +- 0.009
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     605.3
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        13:00:32   Log-Likelihood:            -1.5840e+05
# No. Observations:               11821   AIC:                         3.170e+05
# Df Residuals:                   11738   BIC:                         3.176e+05
# Df Model:                          82
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -1.21e+08   1.27e+07     -9.565      0.000   -1.46e+08   -9.62e+07
# ohe__x0_1.0     6.81e+05   1.91e+04     35.734      0.000    6.44e+05    7.18e+05
# ohe__x1_98001 -1.884e+06   1.79e+05    -10.531      0.000   -2.23e+06   -1.53e+06
# ohe__x1_98002 -1.845e+06   1.77e+05    -10.424      0.000   -2.19e+06    -1.5e+06
# ohe__x1_98003 -1.908e+06   1.81e+05    -10.569      0.000   -2.26e+06   -1.55e+06
# ohe__x1_98155 -1.839e+06    1.9e+05     -9.684      0.000   -2.21e+06   -1.47e+06
# ohe__x1_98166 -1.876e+06   1.84e+05    -10.168      0.000   -2.24e+06   -1.51e+06
# ohe__x1_98168 -1.854e+06   1.83e+05    -10.106      0.000   -2.21e+06   -1.49e+06
# ohe__x1_98177 -1.766e+06   1.92e+05     -9.196      0.000   -2.14e+06   -1.39e+06
# ohe__x1_98178 -1.883e+06   1.81e+05    -10.378      0.000   -2.24e+06   -1.53e+06
# ohe__x1_98188 -1.882e+06   1.82e+05    -10.328      0.000   -2.24e+06   -1.52e+06
# ohe__x1_98198 -1.887e+06   1.82e+05    -10.368      0.000   -2.24e+06   -1.53e+06
# ohe__x1_98199 -1.598e+06   1.91e+05     -8.384      0.000   -1.97e+06   -1.22e+06
# date            129.9379     13.061      9.948      0.000     104.336     155.540
# bedrooms      -2.643e+04   1992.835    -13.263      0.000   -3.03e+04   -2.25e+04
# bathrooms      1.467e+04   3432.054      4.273      0.000    7938.662    2.14e+04
# sqft_living     145.4720      4.484     32.439      0.000     136.682     154.262
# view           5.221e+04   2395.997     21.791      0.000    4.75e+04    5.69e+04
# condition      2.499e+04   2562.185      9.754      0.000       2e+04       3e+04
# grade          5.966e+04   2465.343     24.200      0.000    5.48e+04    6.45e+04
# sqft_above       54.9892      4.292     12.812      0.000      46.576      63.402
# yr_built      -1096.2717     78.993    -13.878      0.000   -1251.112    -941.432
# lat            2.058e+05   8.58e+04      2.399      0.016    3.77e+04    3.74e+05
# long          -1.571e+05   6.27e+04     -2.504      0.012    -2.8e+05   -3.41e+04
# sqft_living15     9.2075      3.916      2.351      0.019       1.531      16.884
# ==============================================================================
# Omnibus:                    10867.710   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1596966.219
# Skew:                           3.927   Prob(JB):                         0.00
# Kurtosis:                      59.397   Cond. No.                     7.40e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.17e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# WAY OVER FITTING but maybe would be better without the low value features: date, sqft_living, sqft_above, sqft_living15

# %%
encoder = OneHotEncoder(categories = 'auto', drop = 'if_binary')
ct = ColumnTransformer(transformers=[('ohe', encoder, ['waterfront', 'zipcode'])], remainder='passthrough')

X = data[cat_cols]
X['waterfront'] = X['waterfront'].astype('str', errors='raise')
X = X.drop(['date', 'sqft_living', 'sqft_above', 'sqft_living15'], axis=1)

y = data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y)

ct.fit(X_train)

X_train_ohe = ct.transform(X_train)
X_test_ohe = ct.transform(X_test)

# scaler = StandardScaler()

# scaler.fit(X_train_ohe)

# X_train_scaled = scaler.transform(X_train_ohe)
# X_test_scaled = scaler.transform(X_test_ohe)

lr = LinearRegression()

lr.fit(X_train_ohe, y_train)

train_preds = lr.predict(X_train_ohe)
test_preds = lr.predict(X_test_ohe)

print(f"Train R2 Score: {r2_score(y_train, train_preds):.3f}")
print(f"Test R2 Score: {r2_score(y_test, test_preds):.3f}")

crossvalidation = KFold(shuffle=True)

scores = cross_val_score(lr, X, y, cv=crossvalidation)

print(f"Scores: {scores.mean():.3f} +- {scores.std():.3f}")

visualizer = ResidualsPlot(lr)

visualizer.fit(X_train_ohe.toarray(), y_train)
visualizer.score(X_test_ohe.toarray(), y_test)
visualizer.show()



y_train = y_train.values.reshape(-1,1)

scaler = RobustScaler()

scaler.fit(X_train_scaled)

X_train_scaled = scaler.transform(X_train_scaled)

X_train_scaled = pd.DataFrame(data = X_train_ohe.toarray(), columns = ct.get_feature_names())


model = sm.OLS(y_train, sm.add_constant(X_train_scaled))
results = model.fit()
results.summary()
# Out:
# <ipython-input-184-f9f5de6a83ba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['waterfront'] = X['waterfront'].astype('str', errors='raise')
# Train R2 Score: 0.749
# Test R2 Score: 0.757
# Scores: 0.648 +- 0.010
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     449.3
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        18:45:01   Log-Likelihood:            -1.6031e+05
# No. Observations:               11821   AIC:                         3.208e+05
# Df Residuals:                   11742   BIC:                         3.214e+05
# Df Model:                          78
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -9.803e+06    9.6e+06     -1.022      0.307   -2.86e+07    9.01e+06
# ohe__x0_1.0    7.032e+05    2.2e+04     31.950      0.000     6.6e+05    7.46e+05
# ohe__x1_98001 -2.477e+05   1.33e+05     -1.859      0.063   -5.09e+05    1.35e+04
# ohe__x1_98002  -2.11e+05    1.3e+05     -1.625      0.104   -4.66e+05    4.36e+04
# ohe__x1_98003 -2.892e+05   1.36e+05     -2.123      0.034   -5.56e+05   -2.22e+04
# ohe__x1_98004  4.709e+05    1.4e+05      3.356      0.001    1.96e+05    7.46e+05
# ohe__x1_98005 -4.139e+04   1.38e+05     -0.299      0.765   -3.12e+05     2.3e+05
# ohe__x1_98006 -5.857e+04   1.34e+05     -0.437      0.662   -3.21e+05    2.04e+05
# ohe__x1_98007 -1.365e+05   1.37e+05     -0.997      0.319   -4.05e+05    1.32e+05
# ohe__x1_98008 -1.102e+05   1.35e+05     -0.817      0.414   -3.74e+05    1.54e+05
# ohe__x1_98010 -1.227e+05   1.18e+05     -1.036      0.300   -3.55e+05     1.1e+05
# ohe__x1_98011 -2.683e+05   1.48e+05     -1.818      0.069   -5.58e+05     2.1e+04
# ohe__x1_98014 -1.796e+05   1.23e+05     -1.455      0.146   -4.21e+05    6.23e+04
# ohe__x1_98019 -2.484e+05   1.33e+05     -1.867      0.062   -5.09e+05    1.24e+04
# ohe__x1_98022 -2.079e+05   1.13e+05     -1.845      0.065   -4.29e+05    1.29e+04
# ohe__x1_98023 -2.928e+05   1.39e+05     -2.100      0.036   -5.66e+05   -1.95e+04
# ohe__x1_98024 -9.493e+04   1.22e+05     -0.780      0.435   -3.33e+05    1.44e+05
# ohe__x1_98027 -1.423e+05   1.26e+05     -1.131      0.258   -3.89e+05    1.04e+05
# ohe__x1_98028 -2.584e+05    1.5e+05     -1.726      0.084   -5.52e+05    3.51e+04
# ohe__x1_98029 -1.601e+05   1.25e+05     -1.276      0.202   -4.06e+05    8.58e+04
